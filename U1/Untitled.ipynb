# %% [markdown]
# ## Exercise 1.13: Visualization of the electric field

# %%
import numpy as np
import matplotlib.pyplot as plt

def efieldq(q0,r,r0):
    # Input: charge q in Coulomb
    #        r: position to find field (in 1,2 or 3 dimensions) in meters
    #        r0: position of charge q0 in meters
    # Output: electric field E at position r in N/C
    dr = r-r0
    drnorm = np.sqrt(dr.dot(dr))
    epsilon0 = 8.854187817e-12
    return q0/(4.0*np.pi*epsilon0)*dr/drnorm**3

r0 = np.array([0.0,0.0])
q0 = 1.0
L = 5
N = 21
x = np.linspace(-L,L,N)
y = np.linspace(-L,L,N)
rx,ry = np.meshgrid(x,y)
Ex = np.zeros((N,N),float)
Ey = np.zeros((N,N),float)
for i in range(len(rx.flat)):
    r = np.array([rx.flat[i],ry.flat[i]])
    Ex.flat[i],Ey.flat[i] = efieldq(q0,r,r0)
plt.quiver(rx,ry,Ex,Ey)
plt.axis('equal')

# The flat command restructures the array into an 1D version of itself, making it easier to iterate over the mesh grid.
# By increasing L we can increase the range, and by increasing N we can increase the resolution
# Out:
# C:\Users\oskar\AppData\Local\Temp\ipykernel_17704\3327217396.py:12: RuntimeWarning: invalid value encountered in true_divide
#   return q0/(4.0*np.pi*epsilon0)*dr/drnorm**3
# (-5.5, 5.5, -5.5, 5.5)

# %%
# Negative charge
# Reasonable results. The longest vectors pointing in the wrong direction. is because they cross the origin for the particles very close to origin
import numpy as np
import matplotlib.pyplot as plt

def efieldq(q0,r,r0):
    # Input: charge q in Coulomb
    #        r: position to find field (in 1,2 or 3 dimensions) in meters
    #        r0: position of charge q0 in meters
    # Output: electric field E at position r in N/C
    dr = r-r0
    drnorm = np.sqrt(dr.dot(dr))
    epsilon0 = 8.854187817e-12
    return q0/(4.0*np.pi*epsilon0)*dr/drnorm**3

r0 = np.array([0.0,0.0])
q0 = -1.0
L = 5
N = 41
x = np.linspace(-L,L,N)
y = np.linspace(-L,L,N)
rx,ry = np.meshgrid(x,y)
Ex = np.zeros((N,N),float)
Ey = np.zeros((N,N),float)
for i in range(len(rx.flat)):
    r = np.array([rx.flat[i],ry.flat[i]])
    Ex.flat[i],Ey.flat[i] = efieldq(q0,r,r0)
plt.quiver(rx,ry,Ex,Ey)
plt.axis('equal')

# The flat command restructures the array into an 1D version of itself, making it easier to iterate over the mesh grid.
# By increasing L we can increase the range, and by increasing N we can increase the resolution
# Out:
# C:\Users\oskar\AppData\Local\Temp\ipykernel_17704\2012805421.py:13: RuntimeWarning: invalid value encountered in true_divide
#   return q0/(4.0*np.pi*epsilon0)*dr/drnorm**3
# (-5.5, 5.5, -5.5, 5.5)

# %%
# c)

import numpy as np
import matplotlib.pyplot as plt

def efieldq(q0,r,r0):
    # Input: charge q in Coulomb
    #        r: position to find field (in 1,2 or 3 dimensions) in meters
    #        r0: position of charge q0 in meters
    # Output: electric field E at position r in N/C
    dr = r-r0
    drnorm = np.sqrt(dr.dot(dr))
    epsilon0 = 8.854187817e-12
    return q0/(4.0*np.pi*epsilon0)*dr/drnorm**3

r0 = np.array([0.01,0.0])
q0 = 0.00000001
L = 5
N = 14
x = np.linspace(-L,L,N)
y = np.linspace(-L,L,N)
rx,ry = np.meshgrid(x,y)
Ex = np.zeros((N,N),float)
Ey = np.zeros((N,N),float)
for i in range(len(rx.flat)):
    r = np.array([rx.flat[i],ry.flat[i]])
    Ex.flat[i],Ey.flat[i] = efieldq(q0,r,r0)
plt.streamplot(rx,ry,Ex,Ey, color = 'blue', density = 0.5)
plt.streamplot(rx,ry,-Ex,Ey, color = 'blue' , density = 0.5)
# plt.streamplot(rx,ry,Ex,-Ey, color = 'blue' , density = 0.5)
# plt.streamplot(rx,ry,-Ex,-Ey, color = 'blue' , density = 0.5)
plt.axis('equal')
# Out:
# (-5.0, 5.5342926126567304, -5.0, 5.0)

# %%
# e)

q0 = 0.1e-6 # C
r0 = np.array([0.01,0]) # m
# (i)
Q = 0.1e-3 #C
r = np.array([1e-3,0]) # m
E = efieldq(q0,r,r0)
print("  (i) F = ",Q*E," N")
# (ii)
Q = -0.1e-3 #C
r = np.array([1e-3,0]) # m
E = efieldq(q0,r,r0)
print(" (ii) F = ",Q*E," N")
# (iii)
Q = 0.2e-3 #C
r = np.array([1e-3,2e-3]) # m
E = efieldq(q0,r,r0)
print("(iii) F = ",Q*E," N")
# Out:
#   (i) F =  [-1109.57429481     0.        ]  N
#  (ii) F =  [1109.57429481   -0.        ]  N
# (iii) F =  [-2064.36041369   458.7467586 ]  N

# %%
# f)
# Plot of two equal charges 

import numpy as np
import matplotlib.pyplot as plt

def efieldq(q0,r,r0):
    # Input: charge q in Coulomb
    #        r: position to find field (in 1,2 or 3 dimensions) in meters
    #        r0: position of charge q0 in meters
    # Output: electric field E at position r in N/C
    dr = r-r0
    drnorm = np.sqrt(dr.dot(dr))
    epsilon0 = 8.854187817e-12
    return q0/(4.0*np.pi*epsilon0)*dr/drnorm**3

r1 = np.array([0.0,0.0])
q1 = 1.0
r2 = np.array([0.5,0.0])
q2 = q1
L = .75
N = 50
x = np.linspace(-L,L,N)
y = np.linspace(-L,L,N)
rx,ry = np.meshgrid(x,y)
Ex = np.zeros((N,N),float)
Ey = np.zeros((N,N),float)
for i in range(len(rx.flat)):
    r = np.array([rx.flat[i],ry.flat[i]])
    Ex.flat[i],Ey.flat[i] = efieldq(q1,r,r1) + efieldq(q2,r,r2)
plt.streamplot(rx,ry,Ex,Ey)
plt.axis('auto')

# The flat command restructures the array into an 1D version of itself, making it easier to iterate over the mesh grid.
# By increasing L we can increase the range, and by increasing N we can increase the resolution
# Out:
# (-0.75, 0.75, -0.75, 0.75)

# %%
# g)
# Net field from two charges, one positive, one negative

import numpy as np
import matplotlib.pyplot as plt

def efieldq(q0,r,r0):
    # Input: charge q in Coulomb
    #        r: position to find field (in 1,2 or 3 dimensions) in meters
    #        r0: position of charge q0 in meters
    # Output: electric field E at position r in N/C
    dr = r-r0
    drnorm = np.sqrt(dr.dot(dr))
    epsilon0 = 8.854187817e-12
    return q0/(4.0*np.pi*epsilon0)*dr/drnorm**3

r1 = np.array([0.0,0.0])
q1 = -0.1*10**-6
r2 = np.array([0.5,0.0])
q2 = -q1
L = .5
N = 40
x = np.linspace(-L+.25,L+.25,N)
y = np.linspace(-L,L,N)
rx,ry = np.meshgrid(x,y)
Ex = np.zeros((N,N),float)
Ey = np.zeros((N,N),float)
for i in range(len(rx.flat)):
    r = np.array([rx.flat[i],ry.flat[i]])
    Ex.flat[i],Ey.flat[i] = efieldq(q1,r,r1) + efieldq(q2,r,r2)

strm = plt.streamplot(rx,ry,Ex,Ey, color = Ey, linewidth=2, cmap='seismic')
plt.colorbar(strm.lines)
plt.plot(0,0,'-ob')
plt.plot(.5,0,'-or')
plt.axis('equal')

# The flat command restructures the array into an 1D version of itself, making it easier to iterate over the mesh grid.
# By increasing L we can increase the range, and by increasing N we can increase the resolution
# Out:
# (-0.25, 0.75, -0.5, 0.5)

# %% [markdown]
# # Exercise 1.18: Linjer på kryss og tvers

# %%
# c)

import numpy as np
import matplotlib.pyplot as plt

def efieldq(q0,r,r0):
    # Input: charge q in Coulomb
    #        r: position to find field (in 1,2 or 3 dimensions) in meters
    #        r0: position of charge q0 in meters
    # Output: electric field E at position r in N/C
    dr = r-r0
    drnorm = np.sqrt(dr.dot(dr))
    epsilon0 = 8.854187817e-12
    return q0/(2.0*np.pi*epsilon0*(drnorm)**3)*dr 

q = 1 # Simplified Q/L
L = 1
N = 50
x = np.linspace(-L,L,N)
y = np.linspace(-L,L,N)
rx,ry = np.meshgrid(x,y)
Ex = np.zeros((N,N),float)
Ey = np.zeros((N,N),float)
for i in range(len(rx.flat)):
    rx0 = np.array([rx.flat[i],0])
    ry0 = np.array([0,ry.flat[i]])
    r = np.array([rx.flat[i],ry.flat[i]])
    Ex.flat[i],Ey.flat[i] = efieldq(q,r,rx0) + efieldq(-q,r,ry0) # Instead of making a new function for the y-axis we generalize the function and input a negatative charge instead
strm = plt.streamplot(rx,ry,Ex,Ey, color = Ex, linewidth=1, cmap='autumn')
plt.streamplot(rx,ry,-Ex,Ey, color = Ex, linewidth=1, cmap='autumn')
plt.colorbar(strm.lines)
plt.vlines(0, -L, L, color = 'blue', label = 'Negativ linjeladning')
plt.hlines(0,-L,L, color = 'red', label = 'Positiv linjeladning')
plt.legend(loc = 'upper left')
plt.axis('scaled')

# The flat command restructures the array into an 1D version of itself, making it easier to iterate over the mesh grid.
# By increasing L we can increase the range, and by increasing N we can increase the resolution
# Out:
# (-1.1129722673141136,
#  1.1129722673141214,
#  -1.1201158628716117,
#  1.12011586287162)

# %%
# b)

import numpy as np
import matplotlib.pyplot as plt

def efieldq(q0,r,r0):
    # Input: charge q in Coulomb
    #        r: position to find field (in 1,2 or 3 dimensions) in meters
    #        r0: position of charge q0 in meters
    # Output: electric field E at position r in N/C
    dr = r-r0
    drnorm = np.sqrt(dr.dot(dr))
    epsilon0 = 8.854187817e-12
    return q0/(2.0*np.pi*epsilon0*(drnorm)**3)*dr 

q = 1 # Simplified Q/L
L = 5
N = 30
x = np.linspace(-L,L,N)
y = np.linspace(-L + 3,L + 3,N)
rx,ry = np.meshgrid(x,y)
Ex = np.zeros((N,N),float)
Ey = np.zeros((N,N),float)
for i in range(len(rx.flat)):
    rx0 = np.array([rx.flat[i],0])
    rx5 = np.array([rx.flat[i],5])
    r = np.array([rx.flat[i],ry.flat[i]])
    Ex.flat[i],Ey.flat[i] = efieldq(-q,r,rx0) + efieldq(q,r,rx5) # Instead of making a new function for the y-axis we generalize the function and input a negatative charge instead
strm = plt.streamplot(rx,ry,Ex,Ey, color = Ex, linewidth=2, cmap='autumn')
plt.colorbar(strm.lines)
plt.hlines(5, -L, L, color = 'red', label = 'Positiv linjeladning')
plt.hlines(0,-L,L, color = 'blue', label = 'Negativ linjeladning')
plt.legend(loc = 'upper left')
plt.axis('equal')

# The flat command restructures the array into an 1D version of itself, making it easier to iterate over the mesh grid.
# By increasing L we can increase the range, and by increasing N we can increase the resolution
# Out:
# (-5.5065710872162486, 5.506571087216256, -2.0, 8.0)

# %%
from magpylib.source.magnet import Cylinder
magpylib.source.magnet
s = Cylinder( mag = [0,0,350], dim = [4,5])
print(s.getB([4,4,4]))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-7f3b69ffb437> in <module>
# ----> 1 from magpylib.source.magnet import Cylinder
#       2 magpylib.source.magnet
#       3 s = Cylinder( mag = [0,0,350], dim = [4,5])
#       4 print(s.getB([4,4,4]))
#
# ModuleNotFoundError: No module named 'magpylib.source'

# %%
import magpylib

# %%
import magpylib.source.magnet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-442acd79bcd7> in <module>
# ----> 1 import magpylib.source.magnet
#
# ModuleNotFoundError: No module named 'magpylib.source'

# %%
import magpylib as magpy

# create collection
coll = magpy.Collection()
for index in range(10):
    cuboid = magpy.magnet.Cuboid(
        magnetization=(0, 0, 1000 * (index%2-.5)),
        dimension=(10,10,10),
        position=(index*10,0,0),
    )
    coll.add(cuboid)

# add 3D-trace
plotly_trace = magpy.graphics.model3d.make_Cuboid(
    backend='matplotlib',
    dimension=(104, 12, 12),
    position=(45, 0, 0),
    alpha=0.5,
)
coll.style.model3d.add_trace(plotly_trace)

coll.style.label='Collection with visible children'
coll.show()

# hide the children default 3D representation
coll.set_children_styles(model3d_showdefault=False)
coll.style.label = 'Collection with hidden children'
coll.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def efieldq(q0,r,r0):
    # Input: charge q in Coulomb
    #        r: position to find field (in 1,2 or 3 dimensions) in meters
    #        r0: position of charge q0 in meters
    # Output: electric field E at position r in N/C
    dr = r-r0
    drnorm = np.sqrt(dr.dot(dr))
    epsilon0 = 8.854187817e-12
    return q0/(4.0*np.pi*epsilon0)*dr/drnorm**3

r1 = np.array([0.0,0.0])
q1 = -0.1*10**6
r2 = np.array([0.5,0.0])
q2 = -q1
L = .5
N = 40
x = np.linspace(-L+.25,L+.25,N)
y = np.linspace(-L,L,N)
rx,ry = np.meshgrid(x,y)
Ex = np.zeros((N,N),float)
Ey = np.zeros((N,N),float)
for i in range(len(rx.flat)):
    r = np.array([rx.flat[i],ry.flat[i]])
    Ex.flat[i],Ey.flat[i] = efieldq(q1,r,r1) + efieldq(q2,r,r2)


fig, ax1 = plt.subplots()
ax1.streamplot(x,y,Ex,Ey, color = Ex)
ax1.xaxis.set_ticks([])
ax1.yaxis.set_ticks([])
ax1.set_aspect('equal')
ax1.set_title('meshgrid function')
# Out:
# Text(0.5, 1.0, 'meshgrid function')

# %%
import numpy as np
import matplotlib.pyplot as plt
# if using a Jupyter notebook, include:
# %matplotlib inline

x = np.arange(-4,4,0.2)
y = np.arange(-4,4,0.2)


X,Y = np.meshgrid(x,y)
Ex = (X + 1)/((X+1)*2 + Y*2) - (X - 1)/((X-1)*2 + Y*2)
Ey = Y/((X+1)*2 + Y*2) - Y/((X-1)*2 + Y*2)


fig, ax = plt.subplots(figsize=(6,6))


ax.streamplot(X,Y,Ex,Ey)


ax.set_aspect('equal')
ax.plot(-1,0,'-or')
ax.plot(1,0,'-ob')
ax.set_title('Stream Plot of Two Point Charges')


plt.show()

# %%
def hei(func):
    def wrapper():
        return 'Hei, ' + func()
    return wrapper

@hei
def greeting_Erik():
    return 'Erik'
@hei
def greeting_Daniel():
    return 'Daniel'

# %%
print(greeting_Erik())
# Out:
# Hei, Erik

# %%
class Human():
    def __innit__(self):
        self._name = 'Oskar'
# Out:
#   Input In [54]
#     self._name
#     ^
# SyntaxError: invalid syntax

# %%
Oskar = Human()

# %%
Oskar._name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
# ----> 1 Oskar._name
#
# AttributeError: 'Human' object has no attribute '_name'
