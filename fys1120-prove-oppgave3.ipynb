# %% [markdown]
# # Prøve-eksamen i Fys1120 H2022 - eksempeloppgave 3
#
# Dette oppgavesettet tilsvarer en av to oppgaver som dere vil få til eksamen. (Denne oppgaven er liten, så den andre oppgaven vil være større). Hver oppgave på eksamen vil bestå av en Jupyter-notebook som dette. Dere arbeider med oppgaven i notebook'en og leverer notebook'en som en pdf file ved å lagre notebook'en og så laste den opp i inspera.
#
# Dere vil kunne får både teori-oppgaver, programmerings-oppgaver og diskusjons-oppgaver som del av eksamen. Alle svarene skal dere skrive i den samme notebook'en.

# %% [markdown]
# ## Krets drevet av en firkantpuls
#
# Vi skal i denne oppgaven studere kretsen som er vist i figuren under. Kretsen består av en spenningskilde, $U(t)$, en kondensator $C$ og en motstand $R$.

# %% [markdown]
# ### Oppgave (a)
# Anta at spenningskilden $U(t) = U_0$ er en konstant. Finn spenningen over kondensatoren etter svært lang tid.

# %% [markdown]
# Ettersom spenningskilden er konstant og statid en del av kretsen vil spenningen over kondensatoren være $U_0$

# %% [markdown]
# __Løsning__
# Etter svært lang tid vil spenningen over kondensatoren svare til spenningen over spenningskilden, $U_0$

# %% [markdown]
# ### Oppgave (b)
# Finn en differensiallikning for spenningen $V_C$ over kondensatoren for en vilkårlig spenningskilde $U(t)$.

# %% [markdown]
# Vi bruker Kirchoffs spenningslov:
# $$
# U(t) - RI - V_C = 0
# $$
# $$
# V_C = U(t) - RI = U(t) - R C\frac{dV_C}{dt}
# $$

# %% [markdown]
# __Løsning__ Vi bruker Kirchoffs spenningslov
# $$U(t) - RI - V_C = 0$$
# Her er $V_C = Q/C$. Strømmen $I$ er gitt som $dQ/dt$ slik at $dV_c/dt = (1/C)dQ/dt = I/C$ slik at $I = C dV_C/dt$. Vi setter dette inn i likningen
# $$U(t) - RC \frac{dV_C}{dt} - V_C = 0$$
# Likningen for $V_C$ blir derfor
# $$\frac{d V_C}{dt} = \frac{1}{RC}\left( U(t) - V_C \right)$$

# %% [markdown]
# ### Oppgave (c)
# Finn $V_C(t)$ når spenningskilden er en firkantpuls:
# $$U(t) = \text{sign}(\sin \omega t)$$
# hvor $\text{sign}(x) = +1$ når $x>0$ og $-1$ når $x<0$. Ved tiden $t=0$ er $I=0$. Du kan dessuten bruke at $R = 100$Ohm, $C = 10^{-3}$F, og $\omega = 2 \pi /T$ hvor $T = 1.0$s.
# Skriv et program som finner strømmen og visualiser denne for et passende tidsintervall.

# %%
import numpy as np
import matplotlib.pyplot as plt

R = 100
N = 100
C = 1E-3
T = 1
ω = 2*np.pi/T
t = np.linspace(0, 10, N)

def U(t):
    return np.sign(np.sin(ω*t))

pulse = U(t)




plt.plot(t, pulse)

# %%
plt.plot(t,V)
